# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/dataset.csv')

# %%
df.head()
# Out:
#                                      id  \
# 0  06f2d3a3-45fd-4f4c-bf85-5f85de8299bc
# 1  072647bd-fa31-41af-a070-95becd391282
# 2  17bb16fc-e048-43a0-8aa3-001b8030b216
# 3  1ba0c577-e57a-4a0a-b1ca-1fde16f5b457
# 4  24770ed6-35f4-419d-8a4c-de2a48505767
#
#                                                 desc    category  \
# 0  Spurs target Morgan Gibbs-White has not travel...    Football
# 1  Man Utd have admired Bryan Mbeumo for some tim...    Football
# 2  Paige Bueckers becomes sixth UConn player to b...  BasketBall
# 3  Indiana Pacers rallied to beat Oklahoma City T...  BasketBall
# 4  Rangers face Panathinaikos in Champions League...    Football
#
#                                                title  \
# 0  Morgan Gibbs-White transfer news: Tottenham ta...
# 1  Bryan Mbeumo joins Man Utd: Brentford forward ...
# 2  WNBA draft: UConn star Paige Bueckers chosen w...
# 3  NBA Finals: Indiana Pacers rally to beat Oklah...
# 4  Rangers vs Panathinaikos: How will Russell Mar...
#
#                                                  img
# 0  post_images/skysports-morgan-gibbs-white_68925...
# 1  post_images/skysports-bryan-mbeumo-manchester-...
# 2  post_images/skysports-paige-bueckers-uconn_687...
# 3  post_images/skysports-nba-tyrese-haliburton_69...
# 4  post_images/skysports-russell-martin-rangers_6...

# %%
df['content'] = df['title'] + " "  + df['desc'] + " " + df['category']

# %%
df
# Out:
#                                       id  \
# 0   06f2d3a3-45fd-4f4c-bf85-5f85de8299bc
# 1   072647bd-fa31-41af-a070-95becd391282
# 2   17bb16fc-e048-43a0-8aa3-001b8030b216
# 3   1ba0c577-e57a-4a0a-b1ca-1fde16f5b457
# 4   24770ed6-35f4-419d-8a4c-de2a48505767
# 5   2fe51bee-0af5-4bea-b7b6-e96517f0e373
# 6   39117ab9-19e4-484c-9c0d-f8f8d00d5ca0
# 7   525b26db-7728-4578-a90a-2370dc6eab5a
# 8   65cdeba8-ef6e-43a6-8979-0ef345eeeb52
# 9   755c4105-5d03-4322-a6ac-8857e3fc766b
# 10  7841724e-3651-47fc-b922-7ddfd6afcb89
# 11  8059f2d0-78e2-4d13-99a7-108cf471c6c0
# 12  84ef1c47-88f1-4a08-8679-138a41c2bf56
# 13  912cba2b-c766-4fef-8b0b-7ad472032baa
# 14  9c4e664c-08eb-485e-9639-485a1edeeda1
# 15  a91fbcf5-69da-4088-85d4-89207776d088
# 16  ab37d591-5d31-4a08-937f-ca80ada05262
# 17  b69625fa-aca8-4a7f-b763-2efa4e46b0c2
# 18  bfe0c57d-330b-4f22-a1bd-3428e111d5f7
# 19  c6e05cef-5237-47b0-af3d-cb4e761993a5
# 20  c7285797-ef9f-4920-9c17-c9dcb1dedb91
# 21  ca37150b-d030-4dcd-8b62-a3535bf31292
# 22  d3b8274b-c3ac-4125-bf21-95c47dcf26f5
# 23  dd58c574-f3cb-4af7-97e1-b61504b5e1e6
# 24  e6af80c5-7400-414a-9d0a-e150bd60b566
# 25  eca885ad-b761-4d4c-a854-480ea9b74877
# 26  efb05be4-a56f-4737-a7e3-b49935ecc475
# 27  f362e1a7-1cf1-4bde-80e9-113ad083e0e3
# 28  f7538649-8eb6-46af-98fd-a35e065e6843
# 29  f9b3cafd-353b-4863-bf5f-96ddf0173414
# 30  fc3f2e8f-7cc0-4783-a65e-6e5b780469e4
#
#                                                  desc    category  \
# 0   Spurs target Morgan Gibbs-White has not travel...    Football
# 1   Man Utd have admired Bryan Mbeumo for some tim...    Football
# 3   post_images/skysports-nba-tyrese-haliburton_69...
# 4   post_images/skysports-russell-martin-rangers_6...
# 5      post_images/istockphoto-1164736873-612x612.jpg
# 6   post_images/skysports-oklahoma-city-thunder_69...
# 7   post_images/skysports-mens-t20-world-cup-troph...
# 8   post_images/skysports-australia-cricket_695894...
# 9   post_images/skysports-josh-taylor-boxing_61789...
# 10  post_images/skysports-paper-talk-brand-refresh...
# 11  post_images/skysports-graham-thorpe-cricket_69...
# 12  post_images/skysports-sir-clive-lloyd-brian-la...
# 13  post_images/skysports-wimbledon-tennis_6970145...
# 14  post_images/skysports-big-mo-boxxer-sky-sports...
# 15  post_images/skysports-nba-finals-oklahoma-city...
# 16  post_images/skysports-dubois-usyk-wembley_6968...
# 17  post_images/skysports-boxing-tyson-fury_679873...
# 18  post_images/skysports-joe-root-england-cricket...
# 19                             post_images/tennis.jpg
# 20  post_images/skysports-mario-barrios-manny-pacq...
# 21  post_images/skysports-mitchell-starc-australia...
# 22  post_images/Screenshot_2025-03-18_085912_2100_...
# 23  post_images/skysports-india-cricket-shafali-ve...
# 24  post_images/skysports-nba-basketball-tyrese-ha...
# 25  post_images/skysports-granit-xhaka-bayer-lever...
# 26  post_images/skysports-jonny-bairstow-cricket_6...
# 27  post_images/skysports-england-women-euro-2025_...
# 28  post_images/skysports-premier-league-laliga_69...
# 29  post_images/skysports-galal-yafai-francisco-ro...
# 30  post_images/skysports-cricket-county-champions...
#
#                                               content
# 0   Morgan Gibbs-White transfer news: Tottenham ta...
# 1   Bryan Mbeumo joins Man Utd: Brentford forward ...
# 2   WNBA draft: UConn star Paige Bueckers chosen w...
# 3   NBA Finals: Indiana Pacers rally to beat Oklah...
# 4   Rangers vs Panathinaikos: How will Russell Mar...
# 5   Fifa club world cup All Big club participate o...
# 6   NBA Finals: Oklahoma City Thunder bounce back ...
# 7   Men's T20 World Cup 2026: Italy reach tourname...
# 8   West Indies vs Australia: Tourists win second ...
# 9   Josh Taylor: Former undisputed super-lightweig...
# 10  Emiliano Martinez: Manchester United fail in l...
# 11  Graham Thorpe to be honoured during England's ...
# 12  West Indies 27 all out: Brian Lara, Sir Clive ...
# 13  Wimbledon: All England Club expansion set to p...
# 14  Big Mo: From American Football to boxing's you...
# 15  NBA Finals: Oklahoma City Thunder one game awa...
# 16  Usyk vs Dubois 2 LIVE: Fight updates, news and...
# 17  Why is Tyson Fury teasing a return – and what ...
# 18  England men's cricket results and fixtures 202...
# 19  world No 1’s first defeat since last August to...
# 20  Manny Pacquiao falls short in world title come...
# 21  West Indies vs Australia: Mitchell Starc in fa...
# 22  The legendary batsman identifies front-foot de...
# 23  Los Angeles Olympics 2028: Dates confirmed for...
# 24  NBA Finals: Indiana Pacers stun Oklahoma City ...
# 25  Granit Xhaka transfer news: Sunderland close t...
# 26  County Championship: Yorkshire thrash Essex by...
# 27  England vs Italy: Lionesses 'rollercoaster' to...
# 28  Marcus Rashford: Man Utd forward is the big wi...
# 29  Francisco Rodriguez fails drug test after endi...
# 30  County Championship: Professional Cricketers' ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['content'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
# Create a mapping from index to News ID
indices = pd.Series(df.index, index=df['id'])

def get_recommendations(news_id, top_n=5):
    idx = indices[news_id]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:top_n+1]
    news_indices = [i[0] for i in sim_scores]
    return df.iloc[news_indices][['id', 'title','desc', 'category','img']]

# %%
import pickle

# %%
pickle.dump(df,open('model/news_list.pkl','wb'))
pickle.dump(cosine_sim,open('model/similarity.pkl','wb'))
